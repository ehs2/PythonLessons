# %%
from gtts import gTTS
import IPython
print('Wie heißt Du?')
myname = input()
tts=gTTS(text='Hallo ' + myname + 'Wie findest Du Jupyter Notebooks?', lang ='de')
tts.save("hallo.mp3")
IPython.display.Audio("hallo.mp3" , autoplay=True)
# Out:
# Wie heißt Du?
# Frens
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
